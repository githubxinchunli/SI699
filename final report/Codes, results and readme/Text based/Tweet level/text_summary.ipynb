# %%
import pandas as pd
text=pd.read_csv('Transferlearning_text.csv')

# %% [markdown]
# ## No adding

# %%
text_svm_no=text.iloc[0:6]
text_svm_no.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_no.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_no=text_svm_no.iloc[0:5,1:]

# %%
text_svm_no=text_svm_no.values.astype(float)

# %%
text_rf_no=text.iloc[6:12]
text_rf_no.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_no.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_no=text_rf_no.iloc[1:,1: ]

# %%
text_rf_no=text_rf_no.values.astype(float)

# %%
text_gdb_no=text.iloc[13:19]
text_gdb_no.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_no.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_no=text_gdb_no.iloc[1:,1: ]

# %%
text_gdb_no=text_gdb_no.values.astype(float)

# %%
text_lr_no=text.iloc[20:26]
text_lr_no.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_no.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_no=text_lr_no.iloc[1:,1: ]

# %%
text_lr_no=text_lr_no.values.astype(float)

# %% [markdown]
# ## Add 10000

# %%
text_svm_add1=text.iloc[28:34]
text_svm_add1.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add1.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add1=text_svm_add1.iloc[1:,1: ]

# %%
text_svm_add1=text_svm_add1.values.astype(float)

# %%
text_rf_add1=text.iloc[35:41]
text_rf_add1.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add1.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add1=text_rf_add1.iloc[1:,1: ]

# %%
text_rf_add1=text_rf_add1.values.astype(float)

# %%
text_gdb_add1=text.iloc[42:48]
text_gdb_add1.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add1.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add1=text_gdb_add1.iloc[1:,1: ]

# %%
text_gdb_add1=text_gdb_add1.values.astype(float)

# %%
text_lr_add1=text.iloc[49:55]
text_lr_add1.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add1.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add1=text_lr_add1.iloc[1:,1: ]

# %%
text_lr_add1=text_lr_add1.values.astype(float)

# %% [markdown]
# ## Add 20000

# %%
text_svm_add2=text.iloc[58:64]
text_svm_add2.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add2.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add2=text_svm_add2.iloc[1:,1: ]

# %%
text_svm_add2=text_svm_add2.values.astype(float)

# %%
text_rf_add2=text.iloc[65:71]
text_rf_add2.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add2.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add2=text_rf_add2.iloc[1:,1: ]

# %%
text_rf_add2=text_rf_add2.values.astype(float)

# %%
text_gdb_add2=text.iloc[72:78]
text_gdb_add2.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add2.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add2=text_gdb_add2.iloc[1:,1: ]

# %%
text_gdb_add2=text_gdb_add2.values.astype(float)

# %%
text_lr_add2=text.iloc[79:85]
text_lr_add2.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add2.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add2=text_lr_add2.iloc[1:,1: ]

# %%
text_lr_add2=text_lr_add2.values.astype(float)

# %% [markdown]
# ## Add 30000

# %%
text_svm_add3=text.iloc[87:93]
text_svm_add3.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add3.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add3=text_svm_add3.iloc[1:,1: ]

# %%
text_svm_add3=text_svm_add3.values.astype(float)

# %%
text_rf_add3=text.iloc[94:100]
text_rf_add3.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add3.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add3=text_rf_add3.iloc[1:,1: ]

# %%
text_rf_add3=text_rf_add3.values.astype(float)

# %%
text_gdb_add3=text.iloc[101:107]
text_gdb_add3.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add3.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add3=text_gdb_add3.iloc[1:,1: ]

# %%
text_gdb_add3=text_gdb_add3.values.astype(float)

# %%
text_lr_add3=text.iloc[108:114]
text_lr_add3.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add3.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add3=text_lr_add3.iloc[1:,1: ]

# %%
text_lr_add3=text_lr_add3.values.astype(float)

# %% [markdown]
# ## Add 40000

# %%
text_svm_add4=text.iloc[116:122]
text_svm_add4.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add4.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_svm_add4=text_svm_add4.iloc[1:,1: ]

# %%
text_svm_add4=text_svm_add4.values.astype(float)

# %%
text_rf_add4=text.iloc[123:129]
text_rf_add4.index=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add4.columns=['RF', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_rf_add4=text_rf_add4.iloc[1:,1: ]

# %%
text_rf_add4=text_rf_add4.values.astype(float)

# %%
text_gdb_add4=text.iloc[130:136]
text_gdb_add4.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add4.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_gdb_add4=text_gdb_add4.iloc[1:,1: ]

# %%
text_gdb_add4=text_gdb_add4.values.astype(float)

# %%
text_lr_add4=text.iloc[137:143]
text_lr_add4.index=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add4.columns=['SVM', 'G+S2', 'G+S3', 'G+T1', 'G+F', 'G+R']
text_lr_add4=text_lr_add4.iloc[1:,1: ]

# %%
text_lr_add4=text_lr_add4.values.astype(float)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(4,5,1)
ax = sns.heatmap(text_svm_no, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('SVM accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,2)
ax = sns.heatmap(text_svm_add1, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('SVM accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,3)
ax = sns.heatmap(text_svm_add2, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('SVM accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,4)
ax = sns.heatmap(text_svm_add3, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('SVM accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,5)
ax = sns.heatmap(text_svm_add4, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('SVM accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,6)
ax = sns.heatmap(text_rf_no, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('RF accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,7)
ax = sns.heatmap(text_rf_add1, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('RF accuracy adding 10000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,8)
ax = sns.heatmap(text_rf_add2, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('RF accuracy adding 20000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,9)
ax = sns.heatmap(text_rf_add3, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('RF accuracy adding 30000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,10)
ax = sns.heatmap(text_rf_add4, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('RF accuracy adding 40000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,11)
ax = sns.heatmap(text_gdb_no, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('GDB accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,12)
ax = sns.heatmap(text_gdb_add1, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('GDB accuracy adding 10000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,13)
ax = sns.heatmap(text_gdb_add2, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('GDB accuracy adding 20000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,14)
ax = sns.heatmap(text_gdb_add3, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('GDB accuracy adding 30000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,15)
ax = sns.heatmap(text_gdb_add4, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('GDB accuracy adding 40000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,16)
ax = sns.heatmap(text_lr_no, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'], annot=True, vmin=0.4, vmax=1)
ax.set_title('LR accuracy no added data')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,17)
ax = sns.heatmap(text_lr_add1, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('LR accuracy adding 10000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,18)
ax = sns.heatmap(text_lr_add2, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('LR accuracy adding 20000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,19)
ax = sns.heatmap(text_lr_add3, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('LR accuracy adding 30000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplot(4,5,20)
ax = sns.heatmap(text_lr_add4, xticklabels=['S2', 'S3', 'T1', 'F', 'R'], yticklabels=['S2', 'S3', 'T1', 'F', 'R'],annot=True,vmin=0.4, vmax=1)
ax.set_title('LR accuracy adding 40000')
ax.set_xlabel('train set')
ax.set_ylabel('test set')
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=360, horizontalalignment='right')

plt.subplots_adjust(left=0.1 , bottom=0.1, right=2.7, top=2.7,
                wspace=0.25, hspace=0.35)

# %%
import seaborn as sns

# %%
all_values=[]
for a in text_svm_no:
    for b in a:
        all_values.append(a)
for a in text_rf_no:
    for b in a:
        all_values.append(a)
for a in text_gdb_no:
    for b in a:
        all_values.append(a)
for a in text_lr_no:
    for b in a:
        all_values.append(a)
for a in text_svm_add1:
    for b in a:
        all_values.append(a)
for a in text_rf_add1:
    for b in a:
        all_values.append(a)
for a in text_gdb_add1:
    for b in a:
        all_values.append(a)
for a in text_lr_add1:
    for b in a:
        all_values.append(a)
for a in text_svm_add2:
    for b in a:
        all_values.append(a)
for a in text_rf_add2:
    for b in a:
        all_values.append(a)
for a in text_gdb_add2:
    for b in a:
        all_values.append(a)
for a in text_lr_add2:
    for b in a:
        all_values.append(a)
for a in text_svm_add3:
    for b in a:
        all_values.append(a)
for a in text_rf_add3:
    for b in a:
        all_values.append(a)
for a in text_gdb_add3:
    for b in a:
        all_values.append(a)
for a in text_lr_add3:
    for b in a:
        all_values.append(a)
for a in text_svm_add4:
    for b in a:
        all_values.append(a)
for a in text_rf_add4:
    for b in a:
        all_values.append(a)
for a in text_gdb_add4:
    for b in a:
        all_values.append(a)
for a in text_lr_add4:
    for b in a:
        all_values.append(a)

# %%
all_values[19]
# Out:
# array([0.76, 0.92, 0.61, 0.81, 0.66])

# %%
all_values_number=[]
for a in all_values:
    for b in a:
        all_values_number.append(b)

# %%
import seaborn as sns
ax=sns.distplot(all_values_number, kde=True)
ax.set_title('Histogram of accuracy numbers for text (tweet-level)')
ax.set_xlabel('Accuracy')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd
text_plus=pd.read_csv('Textsummary.csv')

# %%
text_plus=text_plus[['SVM', 'No add', 'Add 10000', 'Add 20000', 'Add 30000', 'Add 40000']]
text_plus=text_plus[:110]

# %%
text_plus[83:109]
# Out:
#             SVM  No add  Add 10000  Add 20000  Add 30000  Add 40000
# 83           LR  No add  Add 10000  Add 20000  Add 30000  Add 40000
# 84   G+S2->G+S2    0.82       0.82       0.82       0.82       0.82
# 85   G+S2->G+S3    0.63       0.89       0.94       0.95       0.96
# 86   G+S2->G+T1    0.56       0.77        0.8       0.82       0.82
# 87    G+S2->G+F    0.53       0.55        0.6       0.63       0.65
# 88    G+S2->G+R    0.49        0.7       0.76       0.79       0.81
# 89   G+S3->G+S2    0.61       0.61       0.66        0.7       0.72
# 90   G+S3->G+S3    0.96       0.96       0.96       0.96       0.96
# 91   G+S3->G+T1    0.56        0.8       0.83       0.85       0.86
# 92    G+S3->G+F    0.51        0.5       0.56        0.6       0.62
# 93    G+S3->G+R    0.51       0.72       0.78       0.81       0.83
# 94   G+T1->G+S2    0.58       0.59       0.66        0.7       0.73
# 95   G+T1->G+S3    0.63       0.86       0.93       0.95       0.96
# ...

# %%
text_plus_rf=text_plus.iloc[27:53]

# %%
text_plus_rf_drop=text_plus_rf.drop(columns=['SVM'])
text_plus_rf_drop=text_plus_rf_drop.iloc[1:]
text_plus_rf_drop
# Out:
#    No add Add 10000 Add 20000 Add 30000 Add 40000
# 28   0.43      0.61      0.51       0.5       0.5
# 29   0.63      0.94      0.94      0.93      0.93
# 30   0.51      0.69       0.6      0.61      0.64
# 31    0.5      0.68      0.67      0.66      0.66
# 32   0.48       0.5      0.68      0.67      0.67
# 33    0.6      0.78      0.81      0.81      0.81
# 34   0.47      0.49      0.58      0.55      0.51
# 35   0.54      0.73      0.63      0.61       0.6
# 36    0.5      0.66      0.67      0.67      0.66
# 37   0.49      0.52      0.69      0.68      0.68
# 38   0.51      0.72      0.81      0.81      0.81
# 39   0.54      0.91      0.94      0.94      0.93
# 40   0.45       0.6      0.51       0.5       0.5
# 41   0.57      0.68      0.68      0.66      0.66
# 42   0.49      0.64      0.68      0.67      0.67
# 43   0.51       0.8      0.81      0.81      0.81
# 44   0.49      0.93      0.94      0.93      0.93
# 45   0.65      0.64      0.65      0.66       0.7
# ...

# %%
s1=text_plus_rf_drop['No add']
s2=text_plus_rf_drop['Add 10000']
s3=text_plus_rf_drop['Add 20000']
s4=text_plus_rf_drop['Add 30000']
s5=text_plus_rf_drop['Add 40000']
s = pd.concat([s1,s2,s3,s4,s5], axis=0)
s=pd.DataFrame(s, columns=['Accuracy'])
s['Added Test Datapoints']=None
s['Added Test Datapoints'][:25]=0
s['Added Test Datapoints'][25:50]=10000
s['Added Test Datapoints'][50:75]=20000
s['Added Test Datapoints'][75:100]=30000
s['Added Test Datapoints'][100:125]=40000

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
ax = sns.scatterplot(x="No add", y="Add 40000", data=text_plus_rf_drop)

# %%
text_plus_rf.index=['rf', 'G+S2->G+S2', 'G+S2->G+S3', 'G+S2->G+T1', 'G+S2->G+F', 'G+S2->G+R', 
                             'G+S3->G+S2','G+S3->G+S3','G+S3->G+T1','G+S3->G+F','G+S3->G+R','G+T1->G+S2',
                             'G+T1->G+S3','G+T1->G+T1','G+T1->G+F','G+T1->G+R','G+F->G+S2','G+F->G+S3',
                   'G+F->G+T1', 'G+F->G+F', 'G+F->G+R', 'G+R->G+S2', 'G+R->G+S3','G+R->G+T1',
                   'G+R->G+F', 'G+R->G+R']
text_plus_rf.columns=['rf', 'No add', 'Add 10000', 'Add 20000', 'Add 30000', 'Add 40000']
text_plus_rf=text_plus_rf.iloc[1:,1: ]

# %%
text_plus_gdb=text_plus.iloc[55:81]
text_plus_gdb.index=['gdb', 'G+S2->G+S2', 'G+S2->G+S3', 'G+S2->G+T1', 'G+S2->G+F', 'G+S2->G+R', 
                             'G+S3->G+S2','G+S3->G+S3','G+S3->G+T1','G+S3->G+F','G+S3->G+R','G+T1->G+S2',
                             'G+T1->G+S3','G+T1->G+T1','G+T1->G+F','G+T1->G+R','G+F->G+S2','G+F->G+S3',
                   'G+F->G+T1', 'G+F->G+F', 'G+F->G+R', 'G+R->G+S2', 'G+R->G+S3','G+R->G+T1',
                   'G+R->G+F', 'G+R->G+R']
text_plus_gdb.columns=['gdb', 'No add', 'Add 10000', 'Add 20000', 'Add 30000', 'Add 40000']
text_plus_gdb=text_plus_gdb.iloc[1:,1: ]

# %%
text_plus_lr=text_plus.iloc[83:109]
text_plus_lr.index=['lr', 'G+S2->G+S2', 'G+S2->G+S3', 'G+S2->G+T1', 'G+S2->G+F', 'G+S2->G+R', 
                             'G+S3->G+S2','G+S3->G+S3','G+S3->G+T1','G+S3->G+F','G+S3->G+R','G+T1->G+S2',
                             'G+T1->G+S3','G+T1->G+T1','G+T1->G+F','G+T1->G+R','G+F->G+S2','G+F->G+S3',
                   'G+F->G+T1', 'G+F->G+F', 'G+F->G+R', 'G+R->G+S2', 'G+R->G+S3','G+R->G+T1',
                   'G+R->G+F', 'G+R->G+R']
text_plus_lr.columns=['lr', 'No add', 'Add 10000', 'Add 20000', 'Add 30000', 'Add 40000']
text_plus_lr=text_plus_lr.iloc[1:,1: ]

# %%
text_plus_lr
# Out:
#            No add Add 10000 Add 20000 Add 30000 Add 40000 Median
# G+S2->G+S2   0.82      0.82      0.82      0.82      0.82   0.82
# G+S2->G+S3   0.63      0.89      0.94      0.95      0.96   0.94
# G+S2->G+T1   0.56      0.77       0.8      0.82      0.82    0.8
# G+S2->G+F    0.53      0.55       0.6      0.63      0.65    0.6
# G+S2->G+R    0.49       0.7      0.76      0.79      0.81   0.76
# G+S3->G+S2   0.61      0.61      0.66       0.7      0.72   0.66
# G+S3->G+S3   0.96      0.96      0.96      0.96      0.96   0.96
# G+S3->G+T1   0.56       0.8      0.83      0.85      0.86   0.83
# G+S3->G+F    0.51       0.5      0.56       0.6      0.62   0.56
# G+S3->G+R    0.51      0.72      0.78      0.81      0.83   0.78
# G+T1->G+S2   0.58      0.59      0.66       0.7      0.73   0.66
# G+T1->G+S3   0.63      0.86      0.93      0.95      0.96   0.93
# G+T1->G+T1   0.89      0.89      0.89      0.89      0.87   0.89
# ...

# %%
for i in range(len(text_plus_rf)):
    for j in range(5):
        text_plus_rf.iloc[i][j]=float(text_plus_rf.iloc[i][j])

for i in range(len(text_plus_gdb)):
    for j in range(5):
        text_plus_gdb.iloc[i][j]=float(text_plus_gdb.iloc[i][j])
        
for i in range(len(text_plus_lr)):
    for j in range(5):
        text_plus_lr.iloc[i][j]=float(text_plus_lr.iloc[i][j])

# %%
text_plus_rf['Median']=None
for i in range(len(text_plus_rf)):
    text_plus_rf['Median'][i]=text_plus_rf.iloc[i].median()
text_plus_gdb['Median']=None
for i in range(len(text_plus_gdb)):
    text_plus_gdb['Median'][i]=text_plus_gdb.iloc[i].median()
text_plus_lr['Median']=None
for i in range(len(text_plus_lr)):
    text_plus_lr['Median'][i]=text_plus_lr.iloc[i].median()

# %%
text_plus_rf.iloc[:5]['Median']
# Out:
# G+S2->G+S2     0.5
# G+S2->G+S3    0.93
# G+S2->G+T1    0.61
# G+S2->G+F     0.66
# G+S2->G+R     0.67
# Name: Median, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(1,3,1)
ax=sns.barplot(x=text_plus_rf.iloc[20:25]['Median'],y=text_plus_rf.index[20:25])
ax.set_title('Random Forest Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.subplot(1,3,2)
ax=sns.barplot(x=text_plus_gdb.iloc[20:25]['Median'],y=text_plus_gdb.index[20:25])
ax.set_title('GD Boosting Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.subplot(1,3,3)
ax=sns.barplot(x=text_plus_lr.iloc[20:25]['Median'],y=text_plus_lr.index[20:25])
ax.set_title('Logistic Regression Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.subplots_adjust(left=0.125,right=1.5,bottom=0.1, top=0.5,
                wspace=0.45, hspace = 0.2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(1,3,1)

ax=sns.barplot(x=text_plus_rf['Median'],y=text_plus_rf.index)
ax.set_title('Random Forest Median accuracy')
ax.set_xlabel('Median Accuracy')


plt.subplot(1,3,2)
ax=sns.barplot(x=text_plus_gdb['Median'],y=text_plus_gdb.index)
ax.set_title('GD Boosting Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.subplot(1,3,3)
ax=sns.barplot(x=text_plus_lr['Median'],y=text_plus_lr.index)
ax.set_title('Logistic Regression Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.subplots_adjust(left=0.125,right=1.8,bottom=0.1, top=1.3,
                wspace=0.5, hspace = 0.2)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
long_form = text_plus[113:][['No add', 'Add 10000', 'Add 20000', 'Add 30000']]
long_form.columns=['Add', 'Accuracy', 'Combinations', 'Methods']
long_form=long_form.iloc[1:]

# %%
ax=sns.barplot(x=text_plus_rf['Median'],y=text_plus_rf.index)
ax.set_title('Random Forest Median accuracy')
ax.set_xlabel('Median Accuracy')

plt.rcParams['figure.figsize'] = (8.0, 8.0)
