# %%
import pandas as pd
genuine_accounts_users = pd.read_csv('cresci-2017.csv/datasets_full.csv/genuine_accounts.csv/users.csv')
genuine_accounts_tweets = pd.read_csv('cresci-2017.csv/datasets_full.csv/genuine_accounts.csv/tweets.csv')
social_spambots_2_users = pd.read_csv('cresci-2017.csv/datasets_full.csv/social_spambots_2.csv/users.csv')
social_spambots_2_tweets = pd.read_csv('cresci-2017.csv/datasets_full.csv/social_spambots_2.csv/tweets.csv')
social_spambots_3_users = pd.read_csv('cresci-2017.csv/datasets_full.csv/social_spambots_2.csv/users.csv')
social_spambots_3_tweets = pd.read_csv('cresci-2017.csv/datasets_full.csv/social_spambots_2.csv/tweets.csv')
traditional_spambots_1_users = pd.read_csv('cresci-2017.csv/datasets_full.csv/traditional_spambots_1.csv/users.csv', low_memory=False)
traditional_spambots_1_tweets = pd.read_csv('cresci-2017.csv/datasets_full.csv/traditional_spambots_1.csv/tweets.csv', low_memory=False)
fake_followers_users=pd.read_csv('cresci-2017.csv/datasets_full.csv/fake_followers.csv/users.csv', low_memory=False)
fake_followers_tweets=pd.read_csv('cresci-2017.csv/datasets_full.csv/fake_followers.csv/tweets.csv', low_memory=False)
russian_troll_users = pd.read_csv('russian-troll-tweets/users.csv', low_memory=False)
russian_troll_tweets = pd.read_csv('russian-troll-tweets/tweets.csv', low_memory=False)

# %%
df=genuine_accounts_tweets
df1=social_spambots_2_tweets
df2=social_spambots_3_tweets
df3=traditional_spambots_1_tweets
df4=fake_followers_tweets
df5=russian_troll_tweets

# %%
grouped_df=df.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})
grouped_df1=df1.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})
grouped_df2=df2.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})
grouped_df3=df3.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})
grouped_df4=df4.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})
grouped_df5=df5.groupby('user_id').size().to_frame().rename(columns={0:'num_of_tweets'})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.distplot(grouped_df['num_of_tweets'].values, hist=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(2,3,1)
ax = sns.distplot(grouped_df['num_of_tweets'].values, hist=True)
ax.set_title('Genuine Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')
ax.set_ylim(10 ** (-7), 10 ** (-2))

plt.subplot(2,3,2)
ax = sns.distplot(grouped_df1['num_of_tweets'].values, hist=True)
ax.set_title('Social2 Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')

plt.subplot(2,3,3)
ax = sns.distplot(grouped_df2['num_of_tweets'].values, hist=True)
ax.set_title('Social3 Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')

plt.subplot(2,3,4)
ax = sns.distplot(grouped_df3['num_of_tweets'].values, hist=True)
ax.set_title('Traditional1 Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')

plt.subplot(2,3,5)
ax = sns.distplot(grouped_df4['num_of_tweets'].values, hist=True)
ax.set_title('Fake Followers Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')

plt.subplot(2,3,6)
ax = sns.distplot(grouped_df5['num_of_tweets'].values, hist=True)
ax.set_title('Russian Troll Tweets histogram')
ax.set_xlabel('Number of tweets per user')
ax.set_ylabel('Frequency Log Scale')
ax.set_yscale('log')
ax.set_ylim(10 ** (-7), 10 ** (-2))

plt.subplots_adjust(left=0.1 , bottom=0.1, right=2.0, top=1.3,
                wspace=0.25, hspace=0.40)

# %%
grouped_df = df.groupby('user_id').agg(lambda x: x.sum())
# Out:
#           truncated  in_reply_to_status_id  in_reply_to_user_id  \
# user_id
# 678033.0        0.0           5.417542e+20         1.900625e+11
# 722623.0        0.0           3.956188e+20         2.134787e+11
# 755116.0        0.0           9.224814e+20         1.794373e+11
# 755746.0        0.0           4.410604e+20         1.212871e+11
# 785080.0        0.0           7.747332e+20         6.646135e+11
#
#           retweeted_status_id  geo  contributors  retweet_count  reply_count  \
# user_id
# 678033.0         5.103329e+20  0.0           0.0       242725.0          0.0
# 722623.0         2.745486e+20  0.0           0.0       908396.0          0.0
# 755116.0         1.223187e+20  0.0           0.0       105864.0          0.0
# 755746.0         1.344856e+20  0.0           0.0       644062.0          0.0
# 785080.0         2.209495e+20  0.0           0.0       139956.0          0.0
#
#           favorite_count  favorited  retweeted  possibly_sensitive  \
# user_id
# ...

# %%
grouped_df.columns
# Out:
# Index(['truncated', 'in_reply_to_status_id', 'in_reply_to_user_id',
#        'retweeted_status_id', 'geo', 'contributors', 'retweet_count',
#        'reply_count', 'favorite_count', 'favorited', 'retweeted',
#        'possibly_sensitive', 'num_hashtags', 'num_urls', 'num_mentions',
#        'created_at', 'timestamp', 'crawled_at', 'updated'],
#       dtype='object')

# %%
a1 = genuine_accounts_users
a2=genuine_accounts_tweets
c1= social_spambots_2_users
c2=social_spambots_2_tweets
b1=social_spambots_3_users
b2=social_spambots_3_tweets

# %%
social_spambots_2_tweets['num_urls'].median()
# Out:
# 0.0

# %%
genuine_accounts_users['followers_count'].median()
# Out:
# 341.0

# %%
import random
a1.rename(columns={'id': 'user_id'}, inplace=True)
a_merged1 = pd.merge(a1, a2, on = 'user_id', how = 'outer').sample(n=1000, random_state=1)
a_merged2 = pd.merge(a1, a2, on = 'user_id', how = 'outer').drop(index=a_merged1.index).sample(n=1000, random_state=0)
b1.rename(columns={'id': 'user_id'}, inplace=True)
b_merged = pd.merge(b1, b2, on = 'user_id', how = 'outer').sample(n=1000, random_state=1)
c1.rename(columns={'id': 'user_id'}, inplace=True)
c_merged = pd.merge(c1, c2, on = 'user_id', how = 'outer').sample(n=100, random_state=1)

# %%
a_merged1['label']=int(0)
a_merged2['label']=int(0)
b_merged['label']=int(1)
c_merged['label']=int(1)

# %%
a_merged1=a_merged1[['user_id', 'statuses_count', 'followers_count', 'friends_count', 'utc_offset', 
                   'profile_use_background_image', 'favourites_count', 'listed_count','retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions', 'label']]

# %%
a_merged2=a_merged2[['user_id', 'statuses_count', 'followers_count', 'friends_count', 'utc_offset', 
                   'profile_use_background_image', 'favourites_count', 'listed_count','retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions', 'label']]

# %%
b_merged=b_merged[['user_id', 'statuses_count', 'followers_count', 'friends_count', 'utc_offset', 
                   'profile_use_background_image', 'favourites_count', 'listed_count','retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions', 'label']]

# %%
c_merged=c_merged[['user_id', 'statuses_count', 'followers_count', 'friends_count', 'utc_offset', 
                   'profile_use_background_image', 'favourites_count', 'listed_count', 'retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions', 'label']]

# %%
ab_agg = pd.concat([a_merged1, b_merged])
ac_agg=pd.concat([a_merged2, c_merged])

# %%
#b_merged1=pd.merge(c1, c2, on = 'user_id', how = 'outer').drop(index=c_merged.index).sample(n=40000, random_state=0)
#b_merged1['label']=int(1)
#b_merged1=b_merged1[['user_id', 'statuses_count', 'followers_count', 'friends_count', 'utc_offset', 'profile_use_background_image', 'favourites_count', 'listed_count','retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions', 'label']]
#b_merged=pd.concat([b_merged, b_merged1], axis=0)

# %%
for column in ab_agg.columns:
    ab_agg[column]=ab_agg[column].fillna(ab_agg[ab_agg[column].isnull()==False][column].median())

# %%
for column in ac_agg.columns:
    ac_agg[column]=ac_agg[column].fillna(ac_agg[ac_agg[column].isnull()==False][column].median())

# %%
from sklearn.utils import shuffle
ab_agg=shuffle(ab_agg)
ac_agg=shuffle(ac_agg)

# %%
X_train = ab_agg.iloc[:,1:14]
y_train=ab_agg['label']
X_test = ac_agg.iloc[:,1:14]
y_test=ac_agg['label']

# %%
X_train.columns
# Out:
# Index(['statuses_count', 'followers_count', 'friends_count', 'utc_offset',
#        'profile_use_background_image', 'favourites_count', 'listed_count',
#        'retweet_count', 'reply_count', 'favorite_count', 'num_hashtags',
#        'num_urls', 'num_mentions'],
#       dtype='object')

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_transformed = scaler.transform(X_train)
X_test_transformed = scaler.transform(X_test)

# %% [markdown]
# # Baseline Models:

# %% [markdown]
# ## Logistic Regression Classifier

# %%
# build a logistic regression
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(penalty="l1",random_state=0).fit(X_train_transformed, y_train)
import numpy as np
predicted = lr_model.predict(X_test_transformed)
print(np.mean(predicted == y_test))
from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.849945
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84    100000
#            1       0.80      0.92      0.86    100000
#
#    micro avg       0.85      0.85      0.85    200000
#    macro avg       0.86      0.85      0.85    200000
# weighted avg       0.86      0.85      0.85    200000

# %%
lr_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'max_iter': 100,
#  'multi_class': 'warn',
#  'n_jobs': None,
#  'penalty': 'l1',
#  'random_state': 0,
#  'solver': 'warn',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_model.decision_function(X_test)
# Out:
# array([-27640.81997292,   7619.94017297, -47357.91518543, ...,
#          7425.36825009,   7420.88013802,   7413.96441992])

# %% [markdown]
# ## Random Forest Classifier

# %%
# build a Random Forest Classifier
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(max_depth=5, criterion='entropy',
                                   random_state=0).fit(X_train_transformed, y_train)
import numpy as np
predicted = rf_model.predict(X_test_transformed)
print(np.mean(predicted == y_test))
from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.95322
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96    100000
#            1       1.00      0.91      0.95    100000
#
#    micro avg       0.95      0.95      0.95    200000
#    macro avg       0.96      0.95      0.95    200000
# weighted avg       0.96      0.95      0.95    200000

# %%
coef = text_clf.coef_.ravel()
top_positive_coefficients = np.argsort(coef)[-top_features:]
#plt.figure(figsize=(15, 5))
#colors = ['grey' if c < 0 else 'grey' for c in coef[top_positive_coefficients]]
#plt.bar(np.arange(top_features), coef[top_positive_coefficients], color=colors)
#feature_names = np.array(feature_names)
#plt.xticks(np.arange(0, top_features), feature_names[top_positive_coefficients], rotation=60, ha='center')
#plt.show()

# %%
X_train.columns[0:13]
# Out:
# Index(['statuses_count', 'followers_count', 'friends_count', 'utc_offset',
#        'profile_use_background_image', 'favourites_count', 'listed_count',
#        'retweet_count', 'reply_count', 'favorite_count', 'num_hashtags',
#        'num_urls', 'num_mentions'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

feat_importance = rf_model.feature_importances_
pd.DataFrame({'Feature Importance':feat_importance},
            index=X_train.columns[0:13]).plot(kind='barh')

# %%
rf_model.feature_importances_
# Out:
# array([6.93184133e-02, 3.27403692e-01, 1.72070874e-02, 2.45978638e-02,
#        0.00000000e+00, 4.06483730e-01, 1.31880661e-01, 1.18890099e-02,
#        0.00000000e+00, 6.30618271e-03, 3.58922431e-04, 4.27527397e-03,
#        2.79164224e-04])

# %% [markdown]
# ## GDBoosting Classifier

# %%
# build a Random Forest Classifier
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import GradientBoostingClassifier
gdb_model = GradientBoostingClassifier(learning_rate=1.0, max_depth=3, random_state=0).fit(X_train_transformed, y_train)
import numpy as np
predicted = gdb_model.predict(X_test_transformed)
print(np.mean(predicted == y_test))
from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.999875
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    100000
#            1       1.00      1.00      1.00    100000
#
#    micro avg       1.00      1.00      1.00    200000
#    macro avg       1.00      1.00      1.00    200000
# weighted avg       1.00      1.00      1.00    200000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

feat_importance = gdb_model.feature_importances_
pd.DataFrame({'Feature Importance':feat_importance},
            index=X_train.columns[0:13]).plot(kind='barh')

# %%
gdb_model.feature_importances_
# Out:
# array([8.38539390e-01, 1.86376012e-02, 1.83345655e-02, 1.17631116e-03,
#        0.00000000e+00, 1.10503617e-01, 1.27432606e-02, 3.04288367e-08,
#        0.00000000e+00, 0.00000000e+00, 6.52211070e-05, 2.71187115e-09,
#        0.00000000e+00])

# %% [markdown]
# ## SVM Classifier

# %%
# build a Random Forest Classifier
import warnings
warnings.filterwarnings('ignore')
from sklearn.svm import SVC
svm_model = SVC(gamma='auto', max_iter=100).fit(X_train_transformed, y_train)
import numpy as np
predicted = svm_model.predict(X_test_transformed)
print(np.mean(predicted == y_test))
from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.42344
#               precision    recall  f1-score   support
#
#            0       0.46      0.82      0.59    100000
#            1       0.12      0.02      0.04    100000
#
#    micro avg       0.42      0.42      0.42    200000
#    macro avg       0.29      0.42      0.31    200000
# weighted avg       0.29      0.42      0.31    200000

# %%
svm_model.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'auto',
#  'kernel': 'rbf',
#  'max_iter': 100,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_model.decision_function(X_test)
# Out:
# array([-1.21192106, -1.21192106, -1.21192106, ..., -1.21192106,
#        -1.21192106, -1.21192106])
